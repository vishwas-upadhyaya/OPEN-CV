# %%
import cv2
import matplotlib.pyplot as plt

# %%
#img1=cv2.imread('input_dog.jpg')
img2=cv2.imread('nature.jpg')

# %%
#img1=cv2.resize(img1,(812,512))
IMG_SIZE=700
img2=cv2.resize(img2,(IMG_SIZE,IMG_SIZE))
img1=cv2.resize(img2,(812,512))
plt.imshow(img2)
plt.show()

# %%
# dst=cv2.add(img1,img2)

# %%
# dst1=cv2.addWeighted(img1,0.5,img2,0.5,0)

# %%
cv2.imshow('input_dog',img1)
cv2.imshow('nature',img2)
# cv2.imshow('dest',dst)
# cv2.imshow('dest1',dst1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
This is the website for moving things one place to another.
In this website there is two section helper and customer, customer who wants to move his stuffs
and helper is for who want to work(like a delivery guy).

Process--- Customer select from(start location) and to(destination) location and stuffs and submit 
the move, after that this moves is available for all helpers who will be in that area.when the helper
accept it then you can track the move (live tracking in map).Then the customer can also chat with
the helper from the website's chat portal.
In this website i have used websockets for real time chatting, google maps api for showing 
location and tracking system, ajax, javascript etc.
